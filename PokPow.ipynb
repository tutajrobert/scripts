# %%
names = [
       "normal",
       "fire",
       "water",
       "grass",
       "electric",
       "ice",
       "fighting",
       "poison",
       "ground",
       "flying",
       "psychic",
       "bug",
       "rock",
       "ghost",
       "dragon",
       "dark",
       "steel",
        ]

ab = 3
ae = 5
au = -5
an = -12
fairy = True

db = 1
de = -2
du = 2
dn = 6

if fairy == True:
    adv = [[ab] * 18 for i in range(len(names))]
    adv[0][12], adv[0][13], adv[0][16] = au, an, au
    adv[1][1], adv[1][2], adv[1][3], adv[1][5], adv[1][11], adv[1][12], adv[1][14], adv[1][16] = au, au, ae, ae, ae, au, au, ae
    adv[2][1], adv[2][2], adv[2][3], adv[2][8], adv[2][12], adv[2][14] = ae, au, au, ae, ae, au
    adv[3][1], adv[3][2], adv[3][3], adv[3][7], adv[3][8], adv[3][9], adv[3][11], adv[3][12], adv[3][14], adv[3][16] = au, ae, au, au, ae, au, au, ae, au, au
    adv[4][2], adv[4][3], adv[4][4], adv[4][8], adv[4][9], adv[4][14] = ae, au, au, an, ae, au
    adv[5][1], adv[5][2], adv[5][3], adv[5][5], adv[5][8], adv[5][9], adv[5][14], adv[5][16] = au, au, ae, au, ae, ae, ae, au
    adv[6][0], adv[6][5], adv[6][7], adv[6][9], adv[6][10], adv[6][11], adv[6][12], adv[6][13], adv[6][15], adv[6][16], adv[6][17] = ae, ae, au, au, au, au, ae, an, ae, ae, au
    adv[7][3], adv[7][7], adv[7][8], adv[7][12], adv[7][13], adv[7][16], adv[7][17] = ae, au, au, au, au, an, ae
    adv[8][1], adv[8][3], adv[8][4], adv[8][7], adv[8][9], adv[8][11], adv[8][12], adv[8][16] = ae, au, ae, ae, an, au, ae, ae
    adv[9][3], adv[9][4], adv[9][6], adv[9][11], adv[9][12], adv[9][16] = ae, au, ae, ae, au, au
    adv[10][6], adv[10][7], adv[10][10], adv[10][15], adv[10][16] = ae, ae, au, an, au
    adv[11][1], adv[11][3], adv[11][6], adv[11][7], adv[11][9], adv[11][10], adv[11][13], adv[11][15], adv[11][16], adv[11][17] = au, ae, au, au, au, ae, au, ae, au, au
    adv[12][1], adv[12][5], adv[12][6], adv[12][8], adv[12][9], adv[12][11], adv[12][16] = ae, ae, au, au, ae, ae, au
    adv[13][0], adv[13][10], adv[13][13], adv[13][15], adv[13][16] = an, ae, ae, au, au
    adv[14][14], adv[14][16], adv[14][17] = ae, au, an
    adv[15][6], adv[15][10], adv[15][13], adv[15][15], adv[15][16], adv[15][17] = au, ae, ae, au, au, au
    adv[16][1], adv[16][2], adv[16][5], adv[16][12], adv[16][16], adv[16][17] = au, au, ae, ae, au, ae

if fairy == False:
    adv = [[ab] * 17 for i in range(len(names))]
    adv[0][12], adv[0][13], adv[0][16] = au, an, au
    adv[1][1], adv[1][2], adv[1][3], adv[1][5], adv[1][11], adv[1][12], adv[1][14], adv[1][16] = au, au, ae, ae, ae, au, au, ae
    adv[2][1], adv[2][2], adv[2][3], adv[2][8], adv[2][12], adv[2][14] = ae, au, au, ae, ae, au
    adv[3][1], adv[3][2], adv[3][3], adv[3][7], adv[3][8], adv[3][9], adv[3][11], adv[3][12], adv[3][14], adv[3][16] = au, ae, au, au, ae, au, au, ae, au, au
    adv[4][2], adv[4][3], adv[4][4], adv[4][8], adv[4][9], adv[4][14] = ae, au, au, an, ae, au
    adv[5][1], adv[5][2], adv[5][3], adv[5][5], adv[5][8], adv[5][9], adv[5][14], adv[5][16] = au, au, ae, au, ae, ae, ae, au
    adv[6][0], adv[6][5], adv[6][7], adv[6][9], adv[6][10], adv[6][11], adv[6][12], adv[6][13], adv[6][15], adv[6][16] = ae, ae, au, au, au, au, ae, an, ae, ae
    adv[7][3], adv[7][7], adv[7][8], adv[7][12], adv[7][13], adv[7][16] = ae, au, au, au, au, an
    adv[8][1], adv[8][3], adv[8][4], adv[8][7], adv[8][9], adv[8][11], adv[8][12], adv[8][16] = ae, au, ae, ae, an, au, ae, ae
    adv[9][3], adv[9][4], adv[9][6], adv[9][11], adv[9][12], adv[9][16] = ae, au, ae, ae, au, au
    adv[10][6], adv[10][7], adv[10][10], adv[10][15], adv[10][16] = ae, ae, au, an, au
    adv[11][1], adv[11][3], adv[11][6], adv[11][7], adv[11][9], adv[11][10], adv[11][13], adv[11][15], adv[11][16] = au, ae, au, au, au, ae, au, ae, au
    adv[12][1], adv[12][5], adv[12][6], adv[12][8], adv[12][9], adv[12][11], adv[12][16] = ae, ae, au, au, ae, ae, au
    adv[13][0], adv[13][10], adv[13][13], adv[13][15], adv[13][16] = an, ae, ae, au, au
    adv[14][14], adv[14][16] = ae, au
    adv[15][6], adv[15][10], adv[15][13], adv[15][15], adv[15][16] = au, ae, ae, au, au
    adv[16][1], adv[16][2], adv[16][5], adv[16][12], adv[16][16] = au, au, ae, ae, au


def type_pows(name):
    idx = names.index(name)
    eff = []
    uneff = []
    nonaff = []
    for i in range(len(adv[idx])):
        if adv[idx][i] == ae:
            eff.append(names[i])
        elif adv[idx][i] == au:
            uneff.append(names[i])
        elif adv[idx][i] == an:
            nonaff.append(names[i])
    return [eff, uneff, nonaff]

def type_points(name):
    idx = names.index(name)
    points = sum(adv[idx])
    for i in range(len(adv)):
        if adv[i][idx] == an:
            points += dn
        elif adv[i][idx] == ab:
            points += db
        elif adv[i][idx] == au:
            points += du
        elif adv[i][idx] == ae:
            points += de
    return points    

def double_type_points(name1, name2):
    idx1 = names.index(name1)
    idx2 = names.index(name2)
    points = 0
    for i in range(len(adv[idx1])):
        if (adv[idx1][i] == ae) or (adv[idx2][i] == ae):
            points += ae
        elif (adv[idx1][i] == au) and (adv[idx2][i] == au):
            points += au
        elif (adv[idx1][i] == an) and (adv[idx2][i] == an):
            points += an
        else:
            points += ab
    for i in range(len(adv)):
        if (adv[i][idx1] == an) or (adv[i][idx2] == an):
            points += dn
        elif (adv[i][idx1] == ab) and (adv[i][idx2] == ab):
            points += db
        elif (adv[i][idx1] == au) and (adv[i][idx2] == au):
            points += (1.5 * du)
        elif ((adv[i][idx1] == au) or (adv[i][idx1] == ab)) and ((adv[i][idx2] == au) or (adv[i][idx2] == ab)):
            points += du
        elif (adv[i][idx1] == ae) and (adv[i][idx2] == ae):
            points += (4 * de)
        elif ((adv[i][idx1] == ae) or (adv[i][idx1] == ab)) and ((adv[i][idx2] == ae) or (adv[i][idx2] == ab)):
            points += de
        else:
            points += db
    return points

def triple_type_points(name1, name2, name3):
    idx1 = names.index(name1)
    idx2 = names.index(name2)
    idx3 = names.index(name3)
    points = 0

    for i in range(len(adv[idx1])):
        if (adv[idx1][i] == ae) or (adv[idx2][i] == ae) or (adv[idx3][i] == ae):
            points += ae
        elif (adv[idx1][i] == au) and (adv[idx2][i] == au) and (adv[idx3][i] == au):
            points += au
        elif (adv[idx1][i] == an) and (adv[idx2][i] == an) and (adv[idx3][i] == an):
            points += an
        else:
            points += ab
    return points

def quadra_type_points(name1, name2, name3, name4):
    idx1 = names.index(name1)
    idx2 = names.index(name2)
    idx3 = names.index(name3)
    idx4 = names.index(name4)
    points = 0

    for i in range(len(adv[idx1])):
        if (adv[idx1][i] == ae) or (adv[idx2][i] == ae) or (adv[idx3][i] == ae) or (adv[idx4][i] == ae):
            points += ae
        elif (adv[idx1][i] == au) and (adv[idx2][i] == au) and (adv[idx3][i] == au) and (adv[idx4][i] == au):
            points += au
        elif (adv[idx1][i] == an) and (adv[idx2][i] == an) and (adv[idx3][i] == an) and (adv[idx4][i] == an):
            points += an
        else:
            points += ab
    return points


double_points = 0
double_names = ["empty"]
for i in names:
    for j in names:
        res = double_type_points(i, j)
        if res >= double_points:
            double_points = res
            double_names.pop()
            double_names.append([i, j])
        if (res >= 84) and (i > j):
            print(i, j, res)
print(double_names, double_points)


"""
triple_points = 0
triple_names = ["empty"]
for i in names:
    for j in names:
        for k in names:
            res = triple_type_points(i, j, k)
            if res >= triple_points:
                triple_points = res
                triple_names.pop()
                triple_names.append([i, j, k])
            if (res >= 22.5) and (i != j) and (j != k) and (i != k) and (k >= j >= i):
                print(i, j, k, res)
print(triple_names, triple_points)
"""

"""
quadra_points = 0
quadra_names = ["empty"]
for i in names:
    for j in names:
        for k in names:
            for l in names:
                res = quadra_type_points(i, j, k, l)
                if res >= quadra_points:
                    quadra_points = res
                    quadra_names.pop()
                    quadra_names.append([i, j, k, l])
                if (res >= 23.5) and (i != j) and (j != k) and (i != k) and (i != l) and (j != l) and (k != l) and (l >= k >= j >= i):
                    print(i, j, k, l, res)
print(quadra_names, quadra_points)
"""

#print(type_points("water"))
#print(type_points("grass"))
#print(double_type_points("fire", "fighting"))
# Out:
# water ghost 85
# poison dark 85
# ground fire 84
# ground flying 88
# ground ghost 89.0
# ground dark 84
# flying fighting 85.0
# ghost fire 85.0
# ghost electric 84
# ghost fighting 90.0
# steel electric 84.0
# steel fighting 91.0
# steel poison 84.0
# steel ground 93.0
# steel flying 90.0
# steel ghost 91.0
# [['steel', 'ground']] 93.0
# '\nquadra_points = 0\nquadra_names = ["empty"]\nfor i in names:\n    for j in names:\n        for k in names:\n            for l in names:\n                res = quadra_type_points(i, j, k, l)\n                if res >= quadra_points:\n                    quadra_points = res\n                    quadra_names.pop()\n                    quadra_names.append([i, j, k, l])\n                if (res >= 23.5) and (i != j) and (j != k) and (i != k) and (i != l) and (j != l) and (k != l) and (l >= k >= j >= i):\n                    print(i, j, k, l, res)\nprint(quadra_names, quadra_points)\n'

# %%
import pandas as pd
import html5lib
tabele = pd.read_html("http://bulbapedia.bulbagarden.net/wiki/Machop_(Pok%C3%A9mon)/Generation_IV_learnset#By_leveling_up")
print(tabele[0][6:18][1])
# Out:
# 6         Low Kick
# 7             Leer
# 8     Focus Energy
# 9      Karate Chop
# 10       Foresight
# 11    Seismic Toss
# 12         Revenge
# 13     Vital Throw
# 14      Submission
# 15    Wake-Up Slap
# 16      Cross Chop
# 17      Scary Face
# Name: 1, dtype: object
